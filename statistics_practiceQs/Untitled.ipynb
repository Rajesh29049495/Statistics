# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import requests

# %%
df = pd.read_csv("C:\\Users\\Rajesh Singh\\Downloads\\data.csv")

# %%
df.columns
# Out:
# Index(['Patient ID', ' Blood Pressure Before (mmHg)',
#        ' Blood Pressure After (mmHg)'],
#       dtype='object')

# %% [markdown]
# **a. Check whether the distribution of all the classes are the same or not.**

# %%
sns.distplot(df[" Blood Pressure Before (mmHg)"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' Blood Pressure Before (mmHg)', ylabel='Density'>

# %%
sns.distplot(df[" Blood Pressure After (mmHg)"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' Blood Pressure After (mmHg)', ylabel='Density'>

# %% [markdown]
# **Approximately same**

# %% [markdown]
# **b. Check for the equality of variance.**

# %%
df[" Blood Pressure Before (mmHg)"].std()
# Out:
# 6.598278012275075

# %%
df[" Blood Pressure After (mmHg)"].std()
# Out:
# 6.8880221025232276

# %% [markdown]
# **Approximately same with just a little difference**
